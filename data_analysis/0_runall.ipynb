# %%
# from IPython import get_ipython
# get_ipython().magic('reset -sf')
# #chnage fp_data variable in all scripts
# fp_data = '/Users/yasminebassil/Desktop/Data/'
# %store fp_data
# get_ipython().run_line_magic('run', '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/1_calculate_outcomes.ipynb')
# get_ipython().run_line_magic('run', '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/2_merge_data.ipynb')
# #make sure to change save location at the end of script
# get_ipython().run_line_magic('run', '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/3_average_data.ipynb')
# #make sure to change save location at the end of script
# print("Complete")
# Out:
# /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_46645/2602458554.py:2: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -sf')
# Stored 'fp_data' (str)
# ['BNC01', 'BNC02', 'BNC03', 'BNC04', 'BNC05', 'BNC07', 'BNC08', 'BNC09', 'BNC11', 'BNC12', 'BNC23', 'BNC26', 'BNC27', 'BNC28', 'BNC29', 'BNC30', 'BNC31', 'BNC32', 'BNC33', 'BNC34', 'BNC35', 'BNC36', 'BNC37']
# /var/folders/vd/hgkjsb1j7gj04s6dypg9lc0c0000gn/T/ipykernel_46645/4279315902.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_Diff'] = df['X'].diff()
# ...
