# %% [markdown]
# #Input code

# %%
from IPython.core.display import TextDisplayObject
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from pathlib import Path
from matplotlib.backends.backend_pdf import PdfPages
from pathlib import Path
import os
import math

# %%
def GraphMovement(participant):
  fp_file = '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/other_figures/' + participant +'.csv'
  df = pd.read_csv(fp_file)
  df = df[:-1]
  mp.title('xxx')
  df.set_index('X', inplace = True)
  ax = df.groupby('Target_Name')['Z'].plot(legend=False, xlim = [-80, 80], ylim = [-60,80])
  imagepath = Path('/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/other_figures/' + participant +'_graph.png')
  imagepath.parent.mkdir(parents=False, exist_ok=True)
  mp.savefig(imagepath, transparent = True)

# %%
def GraphMovement2(participant):
  target_list = ['Automobile shop', 'Police station ', 'Fire Station', 'Bank', 'Pawn Shop', 'Pizzeria', 'Quattroki Restaurant', 'High School']
  for target in target_list:
    fp_file = '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/other_figures/' + participant +'.csv'
    df = pd.read_csv(fp_file)
    df = df[:-1]
    mp.title(target + ' ' + participant)
    #ax = mp.axes()
    df.set_index('X', inplace = True)
    #ax.set_xlabel('x position in maze')
    #ax.set_ylabel('y position in maze')
    ax = df.groupby(['Participant','Block_num'])['Z'].plot(legend=False, xlim = [-80, 80], ylim = [-60,80])
    imagepath = Path('/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/other_figures/' + participant +'_graph.png')
    imagepath.parent.mkdir(parents=False, exist_ok=True)
    mp.savefig(imagepath)

# %%
def GraphMovement3(participant):
    fp_file = '/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/other_figures/' + participant +'.csv'
    df = pd.read_csv(fp_file)
    df = df[:-1]
    plt.title('xxx')
    df.set_index('X', inplace=True)
    ax = plt.gca()
    colors = ['#fa8485', 'black', '#a3ba32', '#d70b0a', '#0c458e', '#cf5da4', '#097355', '#1f7cf8']  # Add more colors as needed
    targets = df['Target_Name'].unique()
    for i, target in enumerate(targets):
        target_data = df[df['Target_Name'] == target]
        ax.plot(target_data.index, target_data['Z'], color=colors[i])
    ax.set_xlim([-85, 85])
    ax.set_ylim([-85, 85])
    ax.set_aspect('equal')  # Set aspect ratio to 'equal' for square plot
    imagepath = Path('/Users/yasminebassil/Documents/Emory/3_Research/Projects/CogMap_Paper/other_figures/' + participant +'_graph.png')
    imagepath.parent.mkdir(parents=False, exist_ok=True)
    plt.savefig(imagepath, transparent=True)

# %%
GraphMovement3('bnc02')

# %%
GraphMovement3('bnc37')

# %%
os.makedirs(fp_targets+'maps/b3/', exist_ok=True)
GraphMovement('b3')
